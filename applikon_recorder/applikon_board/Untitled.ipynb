# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
data = pd.read_csv('biomas_1s.csv', header=None)
n = len(data)
dt = 1 / n
data = data.iloc[:int(np.floor(n / 2))].to_numpy()
n = len(data)

# %%
fhat = np.fft.fft(data, n)

# %%
#PSD = fhat * np.conj(fhat) / n
freq = 1 / (dt * n) * np.arange(n)
L = np.arange(1, np.floor(n / 2), dtype = int)

# %%
del data

# %%
PSD = PSD[L]
freq = freq[L]

# %%
plot.plot(freq[L], fhat[L])
plot.show()
# Out:
# /home/alexis/anaconda3/envs/cobrapy/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
